# %% [markdown]
# # Conect TF-Serving with gRFC
#
# This notebook shows steps to communicate tf-serving with gRFC.
#
# For that we first need to install some libraries like `grpcio` client (comes with tf package) and `tensorflow-serving-api`.

# %%
# !pip install tensorflow-serving-api==2.7.0
# Out:
# Requirement already satisfied: tensorflow-serving-api==2.7.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (2.7.0)
# Requirement already satisfied: protobuf>=3.6.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow-serving-api==2.7.0) (3.19.6)
# Requirement already satisfied: tensorflow<3,>=2.7.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow-serving-api==2.7.0) (2.9.0)
# Requirement already satisfied: grpcio<2,>=1.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow-serving-api==2.7.0) (1.50.0)
# Requirement already satisfied: six>=1.5.2 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from grpcio<2,>=1.0->tensorflow-serving-api==2.7.0) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.28.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (4.4.0)
# Requirement already satisfied: packaging in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (21.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.7.0)
# Requirement already satisfied: numpy>=1.20 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.23.5)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.1.2)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.14.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.9.0)
# Requirement already satisfied: setuptools in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (65.5.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (14.0.6)
# Requirement already satisfied: astunparse>=1.6.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.6.3)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.9.1)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.12)
# Requirement already satisfied: termcolor>=1.1.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.1.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.14.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from packaging->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.2.2)

# %% [markdown]
# Another library we need for image preprocessing is `keras-image-helper`, this will make our gateway service lightweight without the need to tensorflow package.

# %%
# !pip install keras-image-helper
# Out:
# Requirement already satisfied: keras-image-helper in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (0.0.1)
# Requirement already satisfied: pillow in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from keras-image-helper) (9.3.0)
# Requirement already satisfied: numpy in /home/ubuntu/miniconda3/envs/myenv/lib/python3.10/site-packages (from keras-image-helper) (1.23.5)

# %% [markdown]
# Now we need implement few steps by importing libraries to convert image into specific format (pad_batch).

# %%
import grpc
import tensorflow as tf
from tensorflow_serving.apis import predict_pb2
from tensorflow_serving.apis import prediction_service_pb2_grpc

# %%
# Local host port
host = 'localhost:8500'

# Create channel
channel = grpc.insecure_channel(host)

# Use channel to connect to prediction service
stub = prediction_service_pb2_grpc.PredictionServiceStub(channel) # PredictionServiceStub is used to invoke localhost services
stub

# %% [markdown]
# Now we'll using `stub` to make image predictions on localhost.

# %%
from keras_image_helper import create_preprocessor

# %%
# Create input image preprocessor
preprocessor = create_preprocessor('xception', target_size=(229, 229))

# %%
# Image url
img_url = 'http://bit.ly/mlbookcamp-pants'

# Preprocess image
X = preprocessor.from_url(img_url)
X.shape
# Out:
# (1, 229, 229, 3)

# %%
X
# Out:
# array([[[[-0.09803921, -0.1372549 , -0.18431371],
#          [-0.09803921, -0.1372549 , -0.18431371],
#          [-0.08235294, -0.12156862, -0.16862744],
#          ...,
#          [-0.02745098, -0.02745098, -0.09019607],
#          [-0.04313725, -0.04313725, -0.10588235],
#          [-0.11372548, -0.11372548, -0.17647058]],
#
#         [[-0.09019607, -0.12941176, -0.17647058],
#          [-0.09019607, -0.12941176, -0.17647058],
#          [-0.06666666, -0.10588235, -0.15294117],
#          ...,
#          [-0.02745098, -0.02745098, -0.09019607],
#          [-0.03529412, -0.03529412, -0.09803921],
#          [-0.09803921, -0.09803921, -0.1607843 ]],
#
#         [[-0.09803921, -0.1372549 , -0.18431371],
#          [-0.09803921, -0.1372549 , -0.18431371],
#          [-0.08235294, -0.12156862, -0.16862744],
#          ...,
#          [-0.01960784, -0.01960784, -0.08235294],
#          [-0.03529412, -0.03529412, -0.09803921],
#          [-0.08235294, -0.08235294, -0.14509803]],
#
#         ...,
#
#         [[-0.827451  , -0.8666667 , -0.8901961 ],
#          [-0.8352941 , -0.8745098 , -0.8980392 ],
#          [-0.81960785, -0.88235295, -0.8980392 ],
#          ...,
#          [-0.64705884, -0.85882354, -0.94509804],
#          [-0.64705884, -0.8509804 , -0.9529412 ],
#          [-0.6627451 , -0.8666667 , -0.96862745]],
#
#         [[-0.52156866, -0.5529412 , -0.5764706 ],
#          [-0.54509807, -0.5764706 , -0.6       ],
#          [-0.5686275 , -0.60784316, -0.6313726 ],
#          ...,
#          [-0.6156863 , -0.81960785, -0.92156863],
#          [-0.6156863 , -0.8352941 , -0.94509804],
#          [-0.62352943, -0.84313726, -0.9529412 ]],
#
#         [[-0.5921569 , -0.62352943, -0.64705884],
#          [-0.5686275 , -0.6       , -0.62352943],
#          [-0.5294118 , -0.5686275 , -0.5921569 ],
#          ...,
#          [-0.58431375, -0.8039216 , -0.8980392 ],
#          [-0.5764706 , -0.8039216 , -0.9137255 ],
#          [-0.5921569 , -0.81960785, -0.92941177]]]], dtype=float32)

# %% [markdown]
# Now we need to turn the numpy feature `X` into tensorflow proto.

# %%
# Function to convert numpy array to protobuf
def np_to_protobuf(data):
    return tf.make_tensor_proto(data, shape=data.shape)

# %% [markdown]
# The image is processed and this is what we want to send to our prediction service.
#
# Now we need to prepare the request in json format using `predict_pb2`.

# %%
# Create pb request
pb_request = predict_pb2.PredictRequest()

# Provide model name
pb_request.model_spec.name = 'clothing-model'

# Signature name
pb_request.model_spec.signature_name = 'serving_default'

# Specify Inputs name and assign protobuf feature to it
pb_request.inputs['input_8'].CopyFrom(np_to_protobuf(X))

# %%
# View pb request
pb_request
# Out:
# model_spec {
#   name: "clothing-model"
#   signature_name: "serving_default"
# }
# inputs {
#   key: "input_8"
#   value {
#     dtype: DT_FLOAT
#     tensor_shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 229
#       }
#       dim {
#         size: 229
#       }
#       dim {
#         size: 3
#       }
#     }
#     tensor_content: "\310\310\310\275\214\214\014\276\274\274<\276\310\310\310\275\214\214\014\276\274\274<\276\250\250\250\275\370\370\370\275\254\254,\276\320\320P\275\270\270\270\275\214\214\014\276\260\2600\275\250\250\250\275\204\204\004\276\220\220\020\275\230\230\230\275\370\370\370\275\200\200\200\273\260\2600\275\270\270\270\275\000\301@<\340\340\340\274\230\230\230\275\000\301@<\340\340\340\274\230\230\230\275\300\240\240<\240\240\240\274\260\2600\275\340\320P=\000\301@<\300\300@\274\300\270\270=\340\320P=\000\341\340<\340\330\330=\220\210\210=\300\2600=\
>\264\262\262>\234\232\232>\310\306\306>\264\262\262>\234\232\232>\300\276\276>\254\252\252>\224\222\222>\304\302\302>\260\256\256>\230\226\226>\300\276\276>\254\252\252>\224\222\222>\270\266\266>\244\242\242>\214\212\212>\254\252\252>\230\226\226>\000\375|>\250\246\246>\224\222\222>\370\364t>\314\312\312>\270\266\266>\240\236\236>\340\336\336>\314\312\312>\264\262\262>\304\302\302>\260\256\256>\230\226\226>\270\266\266>\244\242\242>\214\212\212>\244\242\242>\210\206\206>\320\314L>\210\206\206>\330\324T>\230\224\024>\210\206\206>\330\324T>\230\224\024>\224\222\222>\360\354l>\260\254,>\224\222\222>\360\354l>\260\254,>\240\236\236>\204\202\202>\310\304D>\254\252\252>\220\216\216>\340\334\\>\304\302\302>\250\246\246>\210\206\206>\354\352\352>\334\332\332>\270\266\266>\000\377\376>\364\362\362>\340\336\336>\204\203\003?\374\372\372>\350\346\346>\210\207\007?\374\372\372>\344\342\342>\206\205\005?\374 ...
#   }
# }

# %% [markdown]
# We have prepared the request, let's execute it using stub we created earlier.

# %%
pb_response = stub.Predict(pb_request, timeout=20.0) # specify timeout in case service is not responsive

# %%
# Check the output response
pb_response
# Out:
# outputs {
#   key: "dense_7"
#   value {
#     dtype: DT_FLOAT
#     tensor_shape {
#       dim {
#         size: 1
#       }
#       dim {
#         size: 10
#       }
#     }
#     float_val: -2.4946017265319824
#     float_val: -8.939651489257812
#     float_val: -2.9435999393463135
#     float_val: -0.9738842248916626
#     float_val: 15.57507610321045
#     float_val: -2.8537731170654297
#     float_val: -7.355284690856934
#     float_val: 4.215627670288086
#     float_val: -4.100409507751465
#     float_val: -9.35374641418457
#   }
# }
# model_spec {
#   name: "clothing-model"
#   version {
#     value: 1
#   }
#   signature_name: "serving_default"
# }

# %%
# Get the actual value of the output (predictions), it returns python list not numpy array,
# therefore, we don't need to do any conversion to make requests
preds = pb_response.outputs['dense_7'].float_val
preds
# Out:
# [-2.4946017265319824, -8.939651489257812, -2.9435999393463135, -0.9738842248916626, 15.57507610321045, -2.8537731170654297, -7.355284690856934, 4.215627670288086, -4.100409507751465, -9.35374641418457]

# %%
# List of class names
classes = [
    'dress',
    'hat',
    'longsleeve',
    'outwear',
    'pants',
    'shirt',
    'shoes',
    'shorts',
    'skirt',
    't-shirt'
]

# %%
# Check the predictions with the corresponding class names
dict(zip(classes, preds))
# Out:
# {'dress': -2.4946017265319824,
#  'hat': -8.939651489257812,
#  'longsleeve': -2.9435999393463135,
#  'outwear': -0.9738842248916626,
#  'pants': 15.57507610321045,
#  'shirt': -2.8537731170654297,
#  'shoes': -7.355284690856934,
#  'shorts': 4.215627670288086,
#  'skirt': -4.100409507751465,
#  't-shirt': -9.35374641418457}
